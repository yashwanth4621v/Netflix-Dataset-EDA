# %% [markdown]
# # 📊 WEB BLINDERS X WISDOM WELLS
# ## Netflix Dataset Exploratory Data Analysis (EDA)
# **Date:** June 2025
#
# This project explores patterns in the Netflix dataset, covering missing data handling, genre trends, country-wise content, release years, and more to extract valuable insights.

# %% [markdown]
# # **Importing** **Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Loading** **dataset**

# %%
df = pd.read_csv('/content/netflix_titles_with_duplicates.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # **Shape**

# %%
print("Shape:", df.shape)
# Out:
# Shape: (8810, 12)

# %%
#last few rows

df.tail()
# Out:
#      show_id     type                 title         director  \
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8807      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 8808      s2  TV Show         Blood & Water              NaN
# 8809      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807                                                NaN  United States
# 8808  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 8809  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#               date_added  release_year rating   duration  \
# 8805    January 11, 2020          2006     PG     88 min
# ...

# %%
#key info about dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8810 entries, 0 to 8809
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8810 non-null   object
#  1   type          8810 non-null   object
#  2   title         8810 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8800 non-null   object
#  7   release_year  8810 non-null   int64
#  8   rating        8806 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8810 non-null   object
#  11  description   8810 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 826.1+ KB

# %%
#show columns

df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#show datatypes of each column

df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#summary statistics

df.describe()
# Out:
#        release_year
# count   8810.000000
# mean    2014.182406
# std        8.818627
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#unique values per column

df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
 # shows where null values is present

df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
# 8807    False  False  False     False   True    False       False
# 8808    False  False  False      True  False    False       False
# 8809    False  False  False     False  False     True       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# # **null** **values** **count**

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2635
# cast             826
# country          832
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # **null** **values** **count**(**heatmap**)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # **Handling** **null** **values**

# %%
# For numerical columns — fill with median
num_cols = df.select_dtypes(include='number').columns
for col in num_cols:
    if df[col].isnull().sum() > 0:
        median_value = df[col].median()
        df[col] = df[col].fillna(median_value)

# %%
# For categorical columns — fill with mode
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    if df[col].isnull().sum() > 0:
        mode_value = df[col].mode()[0]
        df[col] = df[col].fillna(mode_value)

# %% [markdown]
# # **updated null values count**

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# # **handling duplicates**

# %%
duplicates = df[df.duplicated()]
print("Duplicate records:")
print(duplicates)
print("Duplicates before removal:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate records:
#      show_id     type                 title         director  \
# 8807      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 8808      s2  TV Show         Blood & Water    Rajiv Chilaka
# 8809      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                    cast        country  \
# 8807                                 David Attenborough  United States
# 8808  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 8809  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
#
#               date_added  release_year rating   duration  \
# 8807  September 25, 2021          2020  PG-13     90 min
# 8808  September 24, 2021          2021  TV-MA  2 Seasons
# 8809  September 24, 2021          2021  TV-MA   1 Season
#
#                                               listed_in  \
# 8807                                      Documentaries
# 8808    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water    Rajiv Chilaka
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4      s5  TV Show           Kota Factory    Rajiv Chilaka
#
#                                                 cast        country  \
# 0                                 David Attenborough  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                 David Attenborough  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # **extracting month and year from date**

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] =df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# %% [markdown]
# # **Q1: Content Added by year**

# %%
year_counts = df['year_added'].value_counts().sort_index()
plt.figure(figsize=(10, 5))
sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')
plt.title('Content Added by Year')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-19-157997969.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')

# %% [markdown]
# # **Q2: Top 10 Countires By Content**

# %%
top_countries = df['country'].str.split(',').explode().str.strip().value_counts().head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='coolwarm')
plt.title('Top 10 Countries by Content Count')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-20-1595376122.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='coolwarm')

# %% [markdown]
# # **Q3: Top 10 genres**

# %%
top_genres = df['listed_in'].str.split(',').explode().str.strip().value_counts().head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='magma')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-21-3154994750.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_genres.values, y=top_genres.index, palette='magma')

# %% [markdown]
# # **Q4: Movies vs Tv Show Distribution**

# %%
type_counts = df['type'].value_counts()
plt.figure(figsize=(6, 6))
type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#66c2a5', '#fc8d62'])
plt.title('Distribution of Content Types')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Summary**

# %%
summary = {
    "Most Active Year": year_counts.idxmax(),
    "Most Titles in a Year": year_counts.max(),
    "Top Country": top_countries.idxmax(),
    "Most Common Genre": top_genres.idxmax(),
    "Content Type Distribution": type_counts.to_dict()
}

print("--- Summary Report ---")
for key, value in summary.items():
    print(f"{key}: {value}")
# Out:
# --- Summary Report ---
# Most Active Year: 2019.0
# Most Titles in a Year: 1999
# Top Country: United States
# Most Common Genre: International Movies
# Content Type Distribution: {'Movie': 6131, 'TV Show': 2676}

# %% [markdown]
# # **conclusions:-**
#
# The dataset was first loaded and explored to understand its structure, including the number of rows, columns, and data types.
#
# Null values were identified and handled using statistical methods: median for numeric columns and mode for categorical ones, ensuring cleaner and more reliable data.
#
# Duplicate rows were detected and removed to avoid redundancy and bias in analysis.
#
# The date_added column was converted to datetime format, and new features (year_added, month_added) were extracted for time-based analysis.
#
# The number of titles added each year was visualized to observe trends in Netflix’s content growth over time.
#
# Country-wise content distribution was analyzed, highlighting the most contributing countries, with the United States, India, and the UK leading.
#
# Genre analysis was conducted by splitting the listed_in column to identify the most frequent content categories on Netflix.
#
# A pie chart was used to show the distribution between Movies and TV Shows, confirming that Movies dominate Netflix's library.
#
# A summary report was printed at the end to summarize key findings including the most active year, most common genre, and dominant content type.
